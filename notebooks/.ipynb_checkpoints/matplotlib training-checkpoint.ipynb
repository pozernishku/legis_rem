# %% [markdown]
# ## matplotlib training
#
# Some matplotlib code to train and remember
#
# **Datasets**
# - movies = pd.read_csv('http://bit.ly/imdbratings')
# - ufo = pd.read_csv('http://bit.ly/uforeports', usecols=['City', 'State'], nrows=3)
# - train = pd.read_csv('http://bit.ly/kaggletrain')
# - drinks = pd.read_csv('http://bit.ly/drinksbycountry')
# - orders = pd.read_table('http://bit.ly/chiporders')

# %%
import pandas as pd
import numpy as np
import pprint as pp
import time
from datetime import datetime
import matplotlib.pyplot as plt

# %%
str(datetime.now())
# Out:
# '2018-02-19 10:58:52.849110'

# %%
train = pd.read_csv('http://bit.ly/kaggletrain')

# %%
plt.scatter(train.Age, train.Fare, s=[10, 50, 120], alpha=0.8, c=['red', 'blue', 'green'])
plt.title('Relattion plot')
plt.xlabel('Age in years')
plt.ylabel('Fare in points')
plt.grid()

# %%
tick_val = [10, 20, 30, 40, 50, 90]
tick_lab = ['1s', '20s', '30s', '40s', '50s', '90s']
plt.xticks(tick_val, tick_lab)
# Out:
# ([<matplotlib.axis.XTick at 0x10c98acf8>,
# ...
#  <a list of 6 Text xticklabel objects>)

# %%
plt.show()
