# %%
import os, fnmatch
import io
import csv
from read_data import convert_pdf_to_txt
from PIL import Image
import pytesseract
from wand.image import Image as wi
import hashlib
import pandas as pd
import numpy as np
import pprint as pp
from urllib.request import urlopen
import time
from datetime import datetime
from bs4 import BeautifulSoup
import urllib.request

# %%
def get_size(st):
    if os.path.isfile(st):
        return os.path.getsize(st)

# %%
def conv_pdf(pdf):
    if os.path.isfile(pdf):
        print('--> ' + str(datetime.now()) + ' ' + pdf)
        with open(pdf, 'rb') as f:
            # text from pdf
            bfr = io.BufferedReader(f)
            pdf_text = convert_pdf_to_txt(bfr)
            
            # recognized text (OCR) from pdf
            if len(pdf_text.strip()) <= 50:
                pdf_file = wi(filename=pdf, resolution=200)
                pdfImage = pdf_file.convert('jpeg')
                imageBlobs = []
                for img in pdfImage.sequence:
                    imgPage = wi(image=img)
                    imageBlobs.append(imgPage.make_blob('jpeg'))

                recognized_text = []

                for imgBlob in imageBlobs:
                    im = Image.open(io.BytesIO(imgBlob))
                    text = pytesseract.image_to_string(im, lang = 'eng')
                    recognized_text.append(text)

                recognized_text = '\n\n\n'.join(recognized_text)

            pdf_text = pdf_text if len(pdf_text.strip()) > 50 else recognized_text
            
            return pdf_text

# %%
def get_filename_by_url(url):
    file_id = url.split('=')[-1]
    
    def find(pattern):
        result = []
        for root, dirs, files in os.walk('./pdfs/'):
            for name in files:
                if fnmatch.fnmatch(name, pattern):
                    result.append(os.path.join(root, name))
        return result
    
    f_arr = find('*' + file_id + '.pdf')

    if len(f_arr) == 1:
        return f_arr[0]
    elif len(f_arr) > 1:
        raise ValueError('More than one file exist')
    elif len(f_arr) == 0:
        raise ValueError('No file')

# %%
wy_csv = pd.read_csv('wy_csv-pt1.csv')

# %%
import re

# %%
wy_csv.describe(include='all')
# Out:
#                                                      text chamber  \
# count                                                  31      31
# unique                                                 31       1
# top     \n\n\n\nJudiciary Interim Committee minutes fo...   #TODO
# freq                                                    1      31
#
#                                                      html
# count                                                  31
# unique                                                 31
# top     b'<html>\r\n\r\n<head>\r\n<meta name=Generator...
# freq                                                    1

# %%
wy_csv['html'] = wy_csv.url.apply(urllib.request.urlopen).apply(lambda x: x.read().decode('windows-1252'))

# %%
wy_csv['date'] = wy_csv.session + '/' + wy_csv.date.apply(lambda x: x[0:2]) + '/' + wy_csv.date.apply(lambda x: x[2:4])

# %%
wy_csv['topic'] = '#TODO'

# %%
wy_csv.drop('filename', axis=1, inplace=True)

# %%
wy_csv
# Out:
#                                                   url  \
# 0   http://legisweb.state.wy.us/2008/interim/ag/MI...
# 1   http://legisweb.state.wy.us/2008/interim/abuse...
# 2   http://legisweb.state.wy.us/2008/interim/Jud/M...
# 3   http://legisweb.state.wy.us/2007/interim/lab/M...
# 4   http://legisweb.state.wy.us/2007/interim/water...
# 5   http://legisweb.state.wy.us/2005/interim/lab/M...
# 6   http://legisweb.state.wy.us/2005/interim/schoo...
# 7   http://legisweb.state.wy.us/2005/interim/schoo...
# 8   http://legisweb.state.wy.us/2004/interim/min/M...
# 9   http://legisweb.state.wy.us/2004/interim/ed/MI...
# 10  http://legisweb.state.wy.us/2004/interim/rev/M...
# 11  http://legisweb.state.wy.us/2004/interim/ed/MI...
# 12  http://legisweb.state.wy.us/2003/interim/ag/Te...
# 13  http://legisweb.state.wy.us/2003/interim/ag/MI...
# 14  http://legisweb.state.wy.us/2003/interim/jud/M...
# 15  http://legisweb.state.wy.us/2002/interim/rev/m...
# 16  http://legisweb.state.wy.us/2002/interim/ed/mi...
# 17  http://legisweb.state.wy.us/2002/interim/rev/m...
# 18  http://legisweb.state.wy.us/2001/interim/rev/m...
# 19  http://legisweb.state.wy.us/2001/interim/corp/...
# 20  http://legisweb.state.wy.us/2001/interim/ed/mi...
# 21  http://legisweb.state.wy.us/2001/interim/lab/s...
# 22  http://legisweb.state.wy.us/2001/interim/lab/s...
# 23  http://legisweb.state.wy.us/2001/interim/lab/s...
# 24  http://legisweb.state.wy.us/2001/interim/lab/s...
# 25  http://legisweb.state.wy.us/2001/interim/lab/m...
# 26  http://legisweb.state.wy.us/2001/interim/lab/m...
# 27  http://legisweb.state.wy.us/2001/schoolfinance...
# 28  http://legisweb.state.wy.us/2001/schoolfinance...
# 29  http://legisweb.state.wy.us/2001/interim/jud/m...
# 30  http://legisweb.state.wy.us/2001/interim/rev/m...
#
#                                                  text    state chamber  \
# 0   \n\n\nJoint Agriculture Committee Minutes\n\n\...  wyoming   #TODO
# 1   \n\n\nSelect Committee on Mental Health and Su...  wyoming   #TODO
# 2   \n\n\nJoint Judiciary Committee Minutes\n\n\n\...  wyoming   #TODO
# 3   \n\n\nJoint Labor Committee Minutes for Meetin...  wyoming   #TODO
# 4   \n\n\nSelect Water Committee Minutes for Meeti...  wyoming   #TODO
# 5   Joint Labor Committee Minutes for the Meeting ...  wyoming   #TODO
# 6   \n\n\n\n\n_"Draft Only - Approval Pending"\n\n...  wyoming   #TODO
# 7   \n\n\n\n\n\nSelect Committee on School Facilit...  wyoming   #TODO
# 8   \n\n\n\nJoint Minerals, Business & Economic De...  wyoming   #TODO
# 9   \n\n\n\nJoint Education Interim Committee minu...  wyoming   #TODO
# 10  \n\n\n\nJoint Revenue Committee Minutes for th...  wyoming   #TODO
# 11  \n\n\n\nJoint Meeting of the Management Counci...  wyoming   #TODO
# 12  \n\n\n\nJoint Interim Agriculture, Public Land...  wyoming   #TODO
# 13  \n\n\n\nAgriculture, Public Lands and Water Re...  wyoming   #TODO
# 14  \n\n\n\nJoint Judiciary Interim Committee minu...  wyoming   #TODO
# 15  \n\n\n\nJoint Revenue Interim Committee minute...  wyoming   #TODO
# 16  \n\n\n\nJoint Education Committee Meeting Minu...  wyoming   #TODO
# 17  \n\n\n\nJoint Revenue Committee Minutes for Au...  wyoming   #TODO
# 18  \n\n\n\nJoint Revenue Interim Committee Minute...  wyoming   #TODO
# 19  \n\n\n\nElections Subcommittee of the Joint Co...  wyoming   #TODO
# 20  \n\n\n\nJoint Education Interim Committee minu...  wyoming   #TODO
# 21  \n\n\n\n\n\nLong Term Care Subcommittee of the...  wyoming   #TODO
# 22  \n\n\n\nLong Term Care Subcommittee of the Joi...  wyoming   #TODO
# 23  \n\n\n\nWorkers' Compensation Subcommittee of ...  wyoming   #TODO
# 24  \n\n\n\nWorkers' Compensation Subcommittee of ...  wyoming   #TODO
# 25  \n\n\n\nJoint Labor, Health and Social Service...  wyoming   #TODO
# 26  \n\n\n\nJoint Labor, Health and Social Service...  wyoming   #TODO
# 27  \n\n\n\nMinutes for the Capital Construction m...  wyoming   #TODO
# 28  \n\n\n\nSelect Committee on School Capital Con...  wyoming   #TODO
# 29  \n\n\n\nJudiciary Interim Committee minutes fo...  wyoming   #TODO
# 30  \n\n\n\nJoint Revenue Interim Committee\n\n\n\...  wyoming   #TODO
#
#                                                  html bill_name    md5  \
# 0   <html>\r\n\r\n<head>\r\n<meta http-equiv=Conte...     #TODO  #TODO
# 1   <html>\r\n\r\n<head>\r\n<meta http-equiv=Conte...     #TODO  #TODO
# 2   <html>\r\n\r\n<head>\r\n<meta http-equiv=Conte...     #TODO  #TODO
# 3   <html>\r\n\r\n<head>\r\n<meta http-equiv=Conte...     #TODO  #TODO
# 4   <html>\r\n\r\n<head>\r\n<meta http-equiv=Conte...     #TODO  #TODO
# 5   <html xmlns:v="urn:schemas-microsoft-com:vml"\...     #TODO  #TODO
# 6   <html xmlns:o="urn:schemas-microsoft-com:offic...     #TODO  #TODO
# 7   <html xmlns:v="urn:schemas-microsoft-com:vml"\...     #TODO  #TODO
# 8   <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 9   <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 10  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 11  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 12  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 13  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 14  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 15  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 16  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 17  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 18  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 19  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 20  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 21  <html xmlns:o="urn:schemas-microsoft-com:offic...     #TODO  #TODO
# 22  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 23  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 24  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 25  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 26  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 27  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 28  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 29  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
# 30  <html>\r\n\r\n<head>\r\n<meta name=Generator c...     #TODO  #TODO
#
#    session        date  topic
# 0     2008  2008/09/29  #TODO
# 1     2008  2008/04/24  #TODO
# 2     2008  2008/12/04  #TODO
# 3     2007  2007/12/10  #TODO
# 4     2007  2007/10/03  #TODO
# 5     2005  2005/11/14  #TODO
# 6     2005  2005/09/26  #TODO
# 7     2005  2005/01/11  #TODO
# 8     2004  2004/10/12  #TODO
# 9     2004  2004/07/15  #TODO
# 10    2004  2004/10/05  #TODO
# 11    2004  2004/09/07  #TODO
# 12    2003  2003/09/03  #TODO
# 13    2003  2003/10/20  #TODO
# 14    2003  2003/10/30  #TODO
# 15    2002  2002/11/07  #TODO
# 16    2002  2002/10/23  #TODO
# 17    2002  2002/08/12  #TODO
# 18    2001  2001/06/25  #TODO
# 19    2001  2001/08/13  #TODO
# 20    2001  2001/08/06  #TODO
# 21    2001  2001/10/04  #TODO
# 22    2001  2001/06/26  #TODO
# 23    2001  2001/07/09  #TODO
# 24    2001  2001/08/14  #TODO
# 25    2001  2001/11/27  #TODO
# 26    2001  2001/10/29  #TODO
# 27    2001  2001/11/29  #TODO
# 28    2001  2001/10/23  #TODO
# 29    2001  2001/04/19  #TODO
# 30    2001  2001/08/20  #TODO

# %%
wy_csv.set_index('state', inplace=True)

# %%
wy_csv.shape
# Out:
# (31, 9)

# %%
wy_csv.loc[:, ['url', 'text', 'chamber', 'html', 'bill_name', 'md5', 'session', 'date', 'topic']].to_csv('wy_csv-pt1.csv')

# %%
def get_text(htm):
    soup = BeautifulSoup(htm, 'html5lib')
    for script in soup(["script", "style"]):
        script.extract() # remove script and style tags
    return soup.get_text()

# %%
maine_csv['size'] = maine_csv.url.apply(get_filename_by_url).apply(get_size)
maine_csv['filename'] = maine_csv.url.apply(get_filename_by_url)
maine_csv = maine_csv.sort_values('size')
